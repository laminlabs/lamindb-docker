# %% [markdown]
# The docker image is created with `Dockerfile-dev` and `requirements.txt`.
#
# The jupyter notebook was started with the command
#
# ```
# aws-vault exec lamin -- docker compose -f docker-compose.yml -f docker-compose.dev.yml up
# ```

# %%
import os
import lamindb as ln

from dotenv import load_dotenv
load_dotenv()
# Out:
# 🔶 You are running 3.11.4
# Only python versions 3.8~3.10 are currently tested, use at your own risk.
# 🔶 You haven't yet setup an instance using the CLI: Please call `ln.setup.init()` or `ln.setup.load()`
# True

# %%
ln.setup.login("lawrlee+lamin@gmail.com", password=os.getenv("LAMINDB_PASSWORD"))
# Out:
# ✅ Logged in with handle lawrence-lamin and id 325XQ1LU

# %%
ln.setup.init(
    storage="s3://lamin-lawrence", 
    db="postgresql://lamin:lamin_pw@postgres:5432/lamindb",
    schema="bionty,wetlab"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ln.setup.init(
#       2     storage="s3://lamin-lawrence",
#       3     db="postgresql://lamin:lamin_pw@postgres:5432/lamindb",
#       4     schema="bionty,wetlab"
#       5 )
#
# File /opt/conda/lib/python3.11/site-packages/lamindb_setup/_init_instance.py:137, in init(storage, name, db, schema, _migrate, _test)
#     135 name_str = infer_instance_name(storage=storage, name=name, db=db)
#     136 # test whether instance exists by trying to load it
# --> 137 response = load(
#     138     f"{owner}/{name_str}", _log_error_message=False, migrate=_migrate, _test=_test
#     139 )
#     140 if response is None:
#     141     return None  # successful load!
#
# ...

# %% [markdown]
# Need to also install psycopg2

# %%
# !pip install -q psycopg2-binary

# %%
ln.setup.init(
    storage="s3://lamin-lawrence", 
    db="postgresql://lamin:lamin_pw@postgres:5432/lamindb",
    schema="bionty,wetlab"
)
# Out:
# 🔶 Instance metadata exists, but DB might have been corrupted or deleted. Re-initializing the DB.
# 2023-06-13 23:04:41,007:INFO - Found credentials in environment variables.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/fsspec/registry.py:226, in get_filesystem_class(protocol)
#     225 try:
# --> 226     register_implementation(protocol, _import_class(bit["class"]))
#     227 except ImportError as e:
#
# File /opt/conda/lib/python3.11/site-packages/fsspec/registry.py:249, in _import_class(cls, minv)
#     248 mod, name = cls.rsplit(".", 1)
# --> 249 mod = importlib.import_module(mod)
#     250 return getattr(mod, name)
#
# File /opt/conda/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# ...

# %% [markdown]
# Whoops need to install s3fs! Not sure if this was specified in the install docs.

# %%
# !pip install -q s3fs

# %%
ln.setup.init(
    storage="s3://lamin-lawrence", 
    db="postgresql://lamin:lamin_pw@postgres:5432/lamindb",
    schema="bionty,wetlab"
)
# Out:
# 🔶 Instance metadata exists, but DB might have been corrupted or deleted. Re-initializing the DB.
# 2023-06-13 23:05:41,385:INFO - Found credentials in environment variables.
# 2023-06-13 23:05:44,056:INFO - Found credentials in environment variables.
# ✅ Registered instance on hub: https://lamin.ai/lawrence-lamin/lamindb
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ln.setup.init(
#       2     storage="s3://lamin-lawrence",
#       3     db="postgresql://lamin:lamin_pw@postgres:5432/lamindb",
#       4     schema="bionty,wetlab"
#       5 )
#
# File /opt/conda/lib/python3.11/site-packages/lamindb_setup/_init_instance.py:188, in init(storage, name, db, schema, _migrate, _test)
#     185     return None
#     187 if not isettings._is_db_setup(mute=True)[0]:
# --> 188     load_schema(isettings, init=True)
# ...

# %% [markdown]
# Ah! I had this in my requirements.txt
#
# ```
# lamindb[bionty,wetlab]==0.42a5
# bionty
# ```
#
# which conflicts with this https://lamin.ai/docs/guide/ now. Let me update and try again!
